# %%
import pymysql

# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(dotenv_path="cred.env", override=True)
#prende le variabili e le carica nel sistema operativo
username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

connection_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
print(connection_string)
db_engine = sqlalchemy.create_engine(connection_string)
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW

# %%
Mappapub = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\Mappa-dei-pub-circoli-locali-in-Italia.csv", encoding="latin1", sep=";")
Mappapub
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
Mappapub.shape
# Out:
# (2635, 9)

# %%
Mappapub.dtypes
# Out:
# Comune                              object
# Provincia                           object
# Regione                             object
# Nome                                object
# Anno inserimento                     int64
# Data e ora inserimento              object
# Identificatore in OpenStreetMap      int64
# Longitudine                        float64
# Latitudine                         float64
# dtype: object

# %%
Mappapub.columns
# Out:
# Index(['Comune', 'Provincia', 'Regione', 'Nome', 'Anno inserimento',
#        'Data e ora inserimento', 'Identificatore in OpenStreetMap',
#        'Longitudine', 'Latitudine'],
#       dtype='object')

# %%
Mappapub.describe()
# Out:
#        Anno inserimento  Identificatore in OpenStreetMap  Longitudine  \
# count       2635.000000                     2.635000e+03  2635.000000
# mean        2012.831120                     1.863583e+09    11.440212
# std            1.911466                     1.059639e+09     2.338170
# min         2007.000000                     3.203094e+07     6.708958
# 25%         2012.000000                     9.328297e+08     9.225153
# 50%         2013.000000                     1.790185e+09    11.387645
# 75%         2014.000000                     2.651045e+09    12.604773
# max         2016.000000                     4.012443e+09    18.444577
#
#         Latitudine
# count  2635.000000
# mean     43.997322
# std       2.137994
# min      36.680786
# 25%      42.351325
# 50%      44.905865
# 75%      45.598054
# max      46.983781

# %%
Mappapub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2635 entries, 0 to 2634
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Comune                           2635 non-null   object
#  1   Provincia                        2635 non-null   object
#  2   Regione                          2635 non-null   object
#  3   Nome                             2337 non-null   object
#  4   Anno inserimento                 2635 non-null   int64
#  5   Data e ora inserimento           2635 non-null   object
#  6   Identificatore in OpenStreetMap  2635 non-null   int64
#  7   Longitudine                      2635 non-null   float64
#  8   Latitudine                       2635 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 185.4+ KB

# %%
Mappapub.head(1)
# Out:
#   Comune Provincia Regione Nome  Anno inserimento Data e ora inserimento  \
# 0  ALTRO     ALTRO   ALTRO  NaN              2011   2011-06-25T23:17:43Z
#
#    Identificatore in OpenStreetMap  Longitudine  Latitudine
# 0                       1339088150    13.733257    45.57583

# %%
Mappapub.tail(1)
# Out:
#      Comune              Provincia Regione          Nome  Anno inserimento  \
# 2634  TRANI  BARLETTA-ANDRIA-TRANI  Puglia  Well's Fargo              2009
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2634   2009-08-10T12:44:03Z                        387223648    16.436765
#
#       Latitudine
# 2634   41.267264

# %%
Mappapub.sample()
# Out:
#                      Comune      Provincia Regione                    Nome  \
# 1596  MONSAMPOLO DEL TRONTO  ASCOLI PICENO  Marche  La Bodeguita del Medio
#
#       Anno inserimento Data e ora inserimento  \
# 1596              2014   2014-08-12T00:48:56Z
#
#       Identificatore in OpenStreetMap  Longitudine  Latitudine
# 1596                       3011723370    13.809202   42.885316

# %%
Mappapub["Anno inserimento"].unique()
# Out:
# array([2011, 2015, 2010, 2012, 2014, 2016, 2013, 2008, 2009, 2007])

# %%
filtro_longitudine_min = Mappapub["Longitudine"]>=9
filtro_longitudine_max = Mappapub["Longitudine"]<=10
filtro_LONG = filtro_longitudine_min & filtro_longitudine_max

filtro_latitudine_min = Mappapub["Latitudine"]>=45
filtro_latitudine_max = Mappapub["Latitudine"]<=46
filtro_LAT = filtro_latitudine_min & filtro_latitudine_max

filtro_ind = filtro_LONG & filtro_LAT

Mappapub.loc[filtro_ind,["Nome"]].shape
# Out:
# (306, 1)

# %%
Filtro = Mappapub["Provincia"] == "VICENZA"

Mappapub.loc[Filtro,"Provincia"].shape[0]
# Out:
# 73

# %%
lista_Enoteche=[]

for Nome in Mappapub["Nome"]:
    if pd.notna(Nome):
        if "enoteca" in Nome.lower():
            lista_Enoteche.append(Nome)
            print(Nome)
# Out:
# Enoteca con Cucina""Tirolin""
# Concordia Enoteca
# Enoteca Umberto
# Enoteca ""Al Brindisi""
# Enoteca ""da Massimo""
# Enoteca Il Violino Rosso

# %%
len(lista_Enoteche)
# Out:
# 6

# %%
filtro_Regione1 = Mappapub["Regione"] == "Lazio"
filtro_Regione2 = Mappapub["Regione"] == "Abruzzo"
Filtro_Reg = filtro_Regione1|filtro_Regione2

Mappapub.loc[Filtro_Reg,["Nome","Regione"]]
# Out:
#                      Nome  Regione
# 1801         Franco Marlo    Lazio
# 1802                  NaN    Lazio
# 1803                  NaN    Lazio
# 1804                 fidA    Lazio
# 1805         La Piazzetta    Lazio
# ...                   ...      ...
# 2199       Siren's Corner  Abruzzo
# 2200        Stozza'n'Beer  Abruzzo
# 2201  The Underground Pub  Abruzzo
# 2202         Red Lion Pub  Abruzzo
# 2203         The Docker's  Abruzzo
#
# [337 rows x 2 columns]

# %%
iris = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris["petal_length"].mean()
# Out:
# np.float64(3.758666666666666)

# %%
iris.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
iris.groupby("species")["petal_length"].mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
iris.groupby("species")["sepal_width"].agg(["mean","min","max"])
# Out:
#                   mean  min  max
# species
# Iris-setosa      3.418  2.3  4.4
# Iris-versicolor  2.770  2.0  3.4
# Iris-virginica   2.974  2.2  3.8

# %%
wine = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\wine.csv")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.groupby("quality")["alcohol"].mean()
# Out:
# quality
# 3    10.215000
# 4    10.180093
# 5     9.837783
# 6    10.587553
# 7    11.386006
# 8    11.678756
# 9    12.180000
# Name: alcohol, dtype: float64

# %%
wine.describe() # 4 qualità hanno una media più alta rispetto al set di dati e rispetto alla media del quartile
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
wine.groupby("type")["alcohol"].mean() # si cè differenza tra il rsso ed il bianco se pur lieve
# Out:
# type
# red      10.422983
# white    10.514267
# Name: alcohol, dtype: float64

# %%
wine.groupby("quality")["pH"].mean()
# Out:
# quality
# 3    3.257667
# 4    3.231620
# 5    3.212189
# 6    3.217726
# 7    3.228072
# 8    3.223212
# 9    3.308000
# Name: pH, dtype: float64

# %%
wine.groupby("quality")["sulphates"].mean()
# Out:
# quality
# 3    0.506333
# 4    0.505648
# 5    0.526403
# 6    0.532549
# 7    0.547025
# 8    0.512487
# 9    0.466000
# Name: sulphates, dtype: float64

# %%
wine.groupby("type")["pH"].mean()
# Out:
# type
# red      3.311113
# white    3.188267
# Name: pH, dtype: float64

# %%
wine.groupby("type")["sulphates"].mean()
# Out:
# type
# red      0.658149
# white    0.489847
# Name: sulphates, dtype: float64

# %%
boston = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\boston.csv")
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston.groupby("chas")["medv"].mean() # la vicinanza al fiume determina un aumento del prezzo
# Out:
# chas
# 0    22.093843
# 1    28.440000
# Name: medv, dtype: float64

# %%
boston["crim"].corr(boston["medv"])# con l'aumentare della criminalità diminuisce il valore dell'abitazione
# Out:
# np.float64(-0.3883046085868114)

# %%
boston.groupby("ptratio")["rm"].mean()
# Out:
# ptratio
# 12.6    7.222667
# 13.0    7.406167
# 13.6    7.923000
# 14.4    7.875000
# 14.7    6.246235
# 14.8    6.752333
# 14.9    7.311250
# 15.1    6.816000
# 15.2    6.421923
# 15.3    6.705333
# 15.5    7.241000
# 15.6    6.702000
# 15.9    6.997000
# 16.0    6.230600
# 16.1    6.428800
# 16.4    6.139667
# 16.6    6.344188
# 16.8    6.146750
# 16.9    6.016400
# 17.0    6.868250
# 17.3    6.383000
# 17.4    7.212333
# 17.6    6.822429
# 17.8    6.496130
# 17.9    6.134818
# 18.0    7.218600
# 18.2    6.283000
# 18.3    6.520500
# 18.4    6.285938
# 18.5    6.288750
# 18.6    6.111588
# 18.7    6.406556
# 18.8    5.956000
# 18.9    5.785667
# 19.0    6.453750
# 19.1    6.234882
# 19.2    6.053632
# 19.6    6.224000
# 19.7    6.303250
# 20.1    5.585400
# 20.2    6.024021
# 20.9    6.266273
# 21.0    6.039778
# 21.1    5.888000
# 21.2    6.028533
# 22.0    5.799500
# Name: rm, dtype: float64

# %%
boston.groupby("ptratio")["medv"].mean() # più il valore aumenta e meno insegnanti avremo rispetto agli alunni
# Out:
# ptratio
# 12.6    32.733333
# 13.0    38.025000
# 13.6    50.000000
# 14.4    50.000000
# 14.7    25.717647
# 14.8    25.433333
# 14.9    40.475000
# 15.1    31.600000
# 15.2    26.276923
# 15.3    26.066667
# 15.5    32.700000
# 15.6    30.100000
# 15.9    30.250000
# 16.0    24.320000
# 16.1    24.880000
# 16.4    23.216667
# 16.6    23.856250
# 16.8    22.150000
# 16.9    19.640000
# 17.0    30.600000
# 17.3    24.700000
# 17.4    33.544444
# 17.6    30.700000
# 17.8    26.956522
# 17.9    22.363636
# 18.0    33.100000
# 18.2    22.150000
# 18.3    27.100000
# 18.4    23.131250
# 18.5    23.800000
# 18.6    24.335294
# 18.7    25.122222
# 18.8    17.350000
# 18.9    20.100000
# 19.0    24.900000
# 19.1    22.894118
# 19.2    22.805263
# 19.6    22.575000
# 19.7    21.787500
# 20.1    12.800000
# 20.2    16.611429
# 20.9    21.118182
# 21.0    17.351852
# 21.1    18.900000
# 21.2    17.093333
# 22.0    19.400000
# Name: medv, dtype: float64

# %%
boston["rm"].corr(boston["ptratio"])# correlazione tra stanze e rapporto  alunni/insegnanti
# Out:
# np.float64(-0.3555014945590854)

# %%
boston["medv"].corr(boston["ptratio"])# correlazione tra valore case e rapporto  alunni/insegnanti
# Out:
# np.float64(-0.5077866855375615)

# %%
boston.groupby("rad")["age"].mean()
# Out:
# rad
# 1     45.025000
# 2     64.770833
# 3     49.310526
# 4     60.841818
# 5     69.223478
# 6     60.142308
# 7     40.141176
# 8     67.350000
# 24    89.805303
# Name: age, dtype: float64

# %%
boston.groupby("rad")["tax"].mean()
# Out:
# rad
# 1     291.450000
# 2     260.666667
# 3     246.078947
# 4     335.981818
# 5     331.843478
# 6     372.884615
# 7     304.411765
# 8     301.250000
# 24    666.000000
# Name: tax, dtype: float64

# %%
boston.groupby("rad")["rm"].mean()
# Out:
# rad
# 1     6.555850
# 2     6.649958
# 3     6.473026
# 4     6.133118
# 5     6.393157
# 6     6.104731
# 7     6.647765
# 8     6.950792
# 24    6.022152
# Name: rm, dtype: float64

# %%
import pandas as pd
employees_df = pd.DataFrame({ 
    'employee_id': [101, 102, 103, 104, 105], 
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'], 
    'department_id': [1, 2, 1, 2, 3] })

# %%
departments_df = pd.DataFrame({ 
    'department_id': [1, 2, 3], 
    'department_name': ['HR', 'IT', 'Finance'], 
    'location': ['New York', 'San Francisco', 'Chicago'] })

# %%
employees_df.describe()
# Out:
#        employee_id  department_id
# count     5.000000        5.00000
# mean    103.000000        1.80000
# std       1.581139        0.83666
# min     101.000000        1.00000
# 25%     102.000000        1.00000
# 50%     103.000000        2.00000
# 75%     104.000000        2.00000
# max     105.000000        3.00000

# %%
departments_df.describe()
# Out:
#        department_id
# count            3.0
# mean             2.0
# std              1.0
# min              1.0
# 25%              1.5
# 50%              2.0
# 75%              2.5
# max              3.0

# %%
departments_df.merge(employees_df, how="inner", on = "department_id")
# Out:
#    department_id department_name       location  employee_id     name
# 0              1              HR       New York          101    Alice
# 1              1              HR       New York          103  Charlie
# 2              2              IT  San Francisco          102      Bob
# 3              2              IT  San Francisco          104    David
# 4              3         Finance        Chicago          105     Emma

# %%
employees_df = employees_df.set_index("department_id")
departments_df = departments_df.set_index("department_id")

# %%
employees_df.columns
# Out:
# Index(['employee_id', 'name'], dtype='object')

# %%
departments_df.columns
# Out:
# Index(['department_name', 'location'], dtype='object')

# %%
departments_df.merge(employees_df, how="inner", on = "department_id") # la merge lavora sulle colenne mentre la inner suggli indici
# Out:
#               department_name       location  employee_id     name
# department_id
# 1                          HR       New York          101    Alice
# 1                          HR       New York          103  Charlie
# 2                          IT  San Francisco          102      Bob
# 2                          IT  San Francisco          104    David
# 3                     Finance        Chicago          105     Emma

# %%
query = "SELECT * FROM  dimemployee"
dimemployee = pd.read_sql(query, db_engine)
dimemployee
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0              1               18.0                        14417807
# 1              2                7.0                       253022876
# 2              3               14.0                       509647174
# 3              4                3.0                       112457891
# 4              5                3.0                       112457891
# ..           ...                ...                             ...
# 291          292              290.0                       134219713
# 292          293              272.0                        90836195
# 293          294              277.0                       481044938
# 294          295              290.0                       954276278
# 295          296              294.0                       758596752
#
#      ParentEmployeeNationalIDAlternateKey FirstName           LastName  \
# 0                             446466105.0       Guy            Gilbert
# ...

# %%
query = "SELECT * FROM  dimemployeesalesterritory"
dimemployeesalesterritory = pd.read_sql(query, db_engine)
dimemployeesalesterritory
# Out:
#     EmployeeKey  SalesTerritoryKey
# 0           272                  1
# 1           277                  1
# 2           286                  1
# 3           289                  1
# 4           293                  1
# 5           272                  2
# 6           277                  2
# 7           281                  2
# 8           272                  3
# 9           277                  3
# 10          281                  3
# 11          282                  3
# 12          283                  3
# 13          272                  4
# 14          277                  4
# 15          282                  4
# 16          286                  4
# 17          287                  4
# 18          272                  5
# 19          277                  5
# 20          281                  5
# 21          285                  5
# 22          272                  6
# 23          277                  6
# 24          284                  6
# 25          288                  6
# ...

# %%
merge1 = dimemployee.merge(dimemployeesalesterritory, how="inner", on = "EmployeeKey")

# %%
merge1.columns
# Out:
# Index(['EmployeeKey', 'ParentEmployeeKey', 'EmployeeNationalIDAlternateKey',
#        'ParentEmployeeNationalIDAlternateKey', 'FirstName', 'LastName',
#        'MiddleName', 'NameStyle', 'Title', 'HireDate', 'BirthDate', 'LoginID',
#        'EmailAddress', 'Phone', 'MaritalStatus', 'EmergencyContactName',
#        'EmergencyContactPhone', 'SalariedFlag', 'Gender', 'PayFrequency',
#        'BaseRate', 'VacationHours', 'SickLeaveHours', 'CurrentFlag',
#        'SalesPersonFlag', 'DepartmentName', 'EmployeePhoto', 'Position',
#        'SalesTerritoryKey'],
#       dtype='object')

# %%
merge1
# Out:
#     EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0           272              277.0                       502097814
# 1           272              277.0                       502097814
# 2           272              277.0                       502097814
# 3           272              277.0                       502097814
# 4           272              277.0                       502097814
# 5           272              277.0                       502097814
# 6           277              277.0                       112432117
# 7           277              277.0                       112432117
# 8           277              277.0                       112432117
# 9           277              277.0                       112432117
# 10          277              277.0                       112432117
# 11          277              277.0                       112432117
# 12          277              277.0                       112432117
# ...

# %%
query = "SELECT * FROM  dimsalesterritory"
dimsalesterritory = pd.read_sql(query, db_engine)
dimsalesterritory
# Out:
#     SalesTerritoryKey  SalesTerritoryAlternateKey SalesTerritoryRegion  \
# 0                   1                           1            Northwest
# 1                   2                           2            Northeast
# 2                   3                           3              Central
# 3                   4                           4            Southwest
# 4                   5                           5            Southeast
# 5                   6                           6               Canada
# 6                   7                           7               France
# 7                   8                           8              Germany
# 8                   9                           9            Australia
# 9                  10                          10       United Kingdom
# 10                 11                           0         Corporate HQ
#
#    SalesTerritoryCountry SalesTerritoryGroup  \
# 0          United States       North America
# ...

# %%
merge2 = merge1.merge(dimsalesterritory, how="inner", on ="SalesTerritoryKey")

# %%
merge2
# Out:
#     EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0           272              277.0                       502097814
# 1           272              277.0                       502097814
# 2           272              277.0                       502097814
# 3           272              277.0                       502097814
# 4           272              277.0                       502097814
# 5           272              277.0                       502097814
# 6           277              277.0                       112432117
# 7           277              277.0                       112432117
# 8           277              277.0                       112432117
# 9           277              277.0                       112432117
# 10          277              277.0                       112432117
# 11          277              277.0                       112432117
# 12          277              277.0                       112432117
# ...

# %%
merge2.groupby("SalesTerritoryCountry")["EmployeeKey"].count()
# Out:
# SalesTerritoryCountry
# Australia          3
# Canada             4
# France             4
# Germany            3
# United Kingdom     3
# United States     22
# Name: EmployeeKey, dtype: int64

# %%
merge2.groupby("SalesTerritoryRegion")["EmployeeKey"].count()
# Out:
# SalesTerritoryRegion
# Australia         3
# Canada            4
# Central           5
# France            4
# Germany           3
# Northeast         3
# Northwest         5
# Southeast         4
# Southwest         5
# United Kingdom    3
# Name: EmployeeKey, dtype: int64

# %%
merge2.groupby("SalesTerritoryCountry")["BaseRate"].mean().round(2)
# Out:
# SalesTerritoryCountry
# Australia         47.76
# Canada            41.59
# France            41.59
# Germany           47.76
# United Kingdom    47.76
# United States     39.91
# Name: BaseRate, dtype: float64

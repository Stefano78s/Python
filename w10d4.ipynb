# %%
# !pip install pymysql

# %%
import pymysql

# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(dotenv_path="cred.env", override=True)
#prende le variabili e le carica nel sistema operativo
username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

connection_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
print(connection_string)
db_engine = sqlalchemy.create_engine(connection_string)
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW

# %%
query = "SELECT * FROM dimproduct"
dimproduct = pd.read_sql(query, db_engine)
dimproduct
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
dimproduct.shape
# Out:
# (606, 36)

# %%
 dimproduct.columns
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
 dimproduct.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
 dimproduct.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
 dimproduct.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 253         254          FR-R38B-58                   14.0
# 397         398             HB-M243                    4.0
# 16           17             EC-M092                    NaN
# 424         425             RW-T905                   17.0
# 432         433          FR-R72Y-44                   14.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode            EnglishProductName  \
# 253                    LB                  CM     LL Road Frame - Black, 58
# 397                  None                None        LL Mountain Handlebars
# 16                   None                None             Mountain End Caps
# 424                  None                None            Touring Rear Wheel
# 432                    LB                  CM  ML Road Frame-W - Yellow, 44
#
#                                   SpanishProductName  \
# 253                Cuadro de carretera GB: negro, 58
# 397
# 16
# ...

# %%
 dimproduct["Color"].unique()
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
dimproduct["Weight"].mean()
# Out:
# np.float64(56.1932269503546)

# %%
dimproduct["Weight"].min()
# Out:
# 2.12

# %%
dimproduct["Weight"].max()
# Out:
# 1050.0

# %%
filtro = dimproduct["Weight"] > 100
dimproduct.loc[filtro,"Weight"].shape
# Out:
# (28,)

# %%
dimproduct["DealerPrice"].mean()
# Out:
# np.float64(448.5970597468353)

# %%
dimproduct["DealerPrice"].describe()
# Out:
# count     395.000000
# mean      448.597060
# std       503.225071
# min         1.374000
# 25%        41.994000
# 50%       218.454000
# 75%       722.594900
# max      2146.962000
# Name: DealerPrice, dtype: float64

# %%
filtro = dimproduct["Color"] == "Blue"
dimproduct.loc[filtro,"DealerPrice"].mean().round()
# Out:
# np.float64(516.0)

# %%
filtro_Red = dimproduct["Color"] == "Red"
filtro_Black = dimproduct["Color"] == "Black"
filtro = filtro_Red|filtro_Black
dimproduct.loc[filtro,"DealerPrice"].mean().round()
# Out:
# np.float64(550.0)

# %%
filtro_taglia = dimproduct["Size"] == "42"
filtro_peso = dimproduct["Weight"] > 10
filtro = filtro_taglia&filtro_peso
dimproduct.loc[filtro,"DealerPrice"].max()
# Out:
# 2039.994

# %%
filtro_taglia = dimproduct["Size"] == "42"
filtro_peso = dimproduct["Weight"] > 10
filtro_Colore = dimproduct["Color"] =="Silver"
filtro=filtro_taglia&filtro_peso&filtro_Colore
dimproduct.loc[filtro,["StandardCost","EnglishProductName"]]
# Out:
#      StandardCost         EnglishProductName
# 344       1912.15    Mountain-100 Silver, 42
# 353       1117.86    Mountain-200 Silver, 42
# 354       1265.62    Mountain-200 Silver, 42
# 588        419.78  Mountain-400-W Silver, 42
# 591        308.22    Mountain-500 Silver, 42

# %%
dimproduct.tail(20).loc[:,["StandardCost","DealerPrice",]]
# Out:
#      StandardCost  DealerPrice
# 586        419.78      461.694
# 587        419.78      461.694
# 588        419.78      461.694
# 589        419.78      461.694
# 590        308.22      338.994
# 591        308.22      338.994
# 592        308.22      338.994
# 593        308.22      338.994
# 594        308.22      338.994
# 595        294.58      323.994
# 596        294.58      323.994
# 597        294.58      323.994
# 598        294.58      323.994
# 599        294.58      323.994
# 600         23.97       32.394
# 601         44.95       60.744
# 602         53.94       72.894
# 603        343.65      323.994
# 604        343.65      323.994
# 605        343.65      323.994

# %%
amazon = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\amazon.csv")
amazon
# Out:
#                                               reviewText  Positive
# 0      This is a one of the best apps acording to a b...         1
# 1      This is a pretty good version of the game for ...         1
# 2      this is a really cool game. there are a bunch ...         1
# 3      This is a silly game and can be frustrating, b...         1
# 4      This is a terrific game on any pad. Hrs of fun...         1
# ...                                                  ...       ...
# 19995  this app is fricken stupid.it froze on the kin...         0
# 19996  Please add me!!!!! I need neighbors! Ginger101...         1
# 19997  love it!  this game. is awesome. wish it had m...         1
# 19998  I love love love this app on my side of fashio...         1
# 19999  This game is a rip off. Here is a list of thin...         0
#
# [20000 rows x 2 columns]

# %%
amazon.shape
# Out:
# (20000, 2)

# %%
amazon.sample(10)
# Out:
#                                               reviewText  Positive
# 11801  Very loud and bothersome. Perfect for rock har...         1
# 2057   Just a fun app to play around with and pass ti...         1
# 15813  This app has allowed me to clean up all of my ...         1
# 2552   I've used this app in my last two smart phones...         1
# 11400  I have never played the card game before playi...         1
# 12696  love spinning for dinned ideas or the search w...         1
# 1228   I use the Zedge website then found out about t...         1
# 10000  opponats always have the right card to play. Y...         0
# 3559   Doodle God is one of the worst games I have se...         0
# 3668   Great way to store stuff off your device.  Als...         1

# %%
amazon.columns
# Out:
# Index(['reviewText', 'Positive'], dtype='object')

# %%
amazon["Positive"].sum()
# Out:
# np.int64(15233)

# %%
amazon["Positive"].value_counts()
# Out:
# Positive
# 1    15233
# 0     4767
# Name: count, dtype: int64

# %%
diabetes = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\diabetes.csv")
diabetes
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.sample(5)
# Out:
#      Number of times pregnant  \
# 216                         5
# 282                         7
# 218                         5
# 313                         3
# 681                         0
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 216                                                109
# 282                                                133
# 218                                                 85
# 313                                                113
# 681                                                162
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 216                                62                                41
# 282                                88                                15
# 218                                74                                22
# 313                                50                                10
# ...

# %%
diabetes.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
filtro_età_min = diabetes["Age (years)"] >= 20
filtro_età_max = diabetes["Age (years)"] <= 29
filtro1 = filtro_età_min & filtro_età_max
diabetes.loc[filtro1,["Age (years)","Diastolic blood pressure (mm Hg)"]].mean().round(2)
# Out:
# Age (years)                         24.31
# Diastolic blood pressure (mm Hg)    65.35
# dtype: float64

# %%
filtro_età_min = diabetes["Age (years)"] >= 30
filtro_età_max = diabetes["Age (years)"] <= 39

filtro2 = filtro_età_min & filtro_età_max
diabetes.loc[filtro2,["Age (years)","Diastolic blood pressure (mm Hg)"]].mean().round(2)
# Out:
# Age (years)                         34.11
# Diastolic blood pressure (mm Hg)    69.67
# dtype: float64

# %%
filtro_età_min = diabetes["Age (years)"] >= 40
filtro_età_max = diabetes["Age (years)"] <= 50

filtro3 = filtro_età_min & filtro_età_max
diabetes.loc[filtro3,["Age (years)","Diastolic blood pressure (mm Hg)"]].mean().round(2)
# Out:
# Age (years)                         43.88
# Diastolic blood pressure (mm Hg)    74.21
# dtype: float64

# %%
insurance = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\insurance.csv")
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.sample(10)
# Out:
#      age     sex     bmi  children smoker     region      charges
# 703   34  female  26.410         1     no  northwest   5385.33790
# 328   64  female  33.800         1    yes  southwest  47928.03000
# 414   19  female  35.150         0     no  northwest   2134.90150
# 769   38  female  19.475         2     no  northwest   6933.24225
# 970   50  female  28.160         3     no  southeast  10702.64240
# 711   50  female  23.540         2     no  southeast  10107.22060
# 49    36    male  35.200         1    yes  southeast  38709.17600
# 35    19    male  20.425         0     no  northwest   1625.43375
# 603   64  female  39.050         3     no  southeast  16085.12750
# 895   61  female  44.000         0     no  southwest  13063.88300

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
insurance.groupby("region")["charges"].mean().round(2)
# Out:
# region
# northeast    13406.38
# northwest    12417.58
# southeast    14735.41
# southwest    12346.94
# Name: charges, dtype: float64

# %%
insurance.groupby("smoker")["charges"].mean().round(2)
# Out:
# smoker
# no      8434.27
# yes    32050.23
# Name: charges, dtype: float64

# %%
insurance.groupby("sex")["charges"].mean().round(2)
# Out:
# sex
# female    12569.58
# male      13956.75
# Name: charges, dtype: float64

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance["charges"].min()
# Out:
# 1121.8739

# %%
q1 = insurance['bmi'].quantile(0.25)
q2 = insurance['bmi'].quantile(0.50)
q3 = insurance['bmi'].quantile(0.75)

filtro_q1_bmi= insurance["bmi"]<= q1
print(insurance.loc[filtro_q1_bmi,"charges"].min())
print(insurance.loc[filtro_q1_bmi,"charges"].max())
print(insurance.loc[filtro_q1_bmi,"charges"].mean().round(2))
# Out:
# 1121.8739
# 38245.59327
# 10360.66

# %%
filtro_q2_bmi= insurance["bmi"]<= q2
filtro_q1_bmi= insurance["bmi"]> q1
filtro_q1_2 = filtro_q2_bmi & filtro_q1_bmi

print(insurance.loc[filtro_q1_2,"charges"].min())
print(insurance.loc[filtro_q1_2,"charges"].max())
print(insurance.loc[filtro_q1_2,"charges"].mean().round(2))
# Out:
# 1131.5066
# 62592.87309
# 11407.83

# %%
filtro_q2_bmi= insurance["bmi"]> q2
filtro_q3_bmi= insurance["bmi"]<= q3
filtro_q2_3 = filtro_q2_bmi & filtro_q3_bmi

print(insurance.loc[filtro_q2_3,"charges"].min())
print(insurance.loc[filtro_q2_3,"charges"].max())
print(insurance.loc[filtro_q2_3,"charges"].mean().round(2))
# Out:
# 1135.9407
# 60021.39897
# 14358.17

# %%
iltro_q3_bmi= insurance["bmi"]> q3
print(insurance.loc[filtro_q1_bmi,"charges"].min())
filtro_q3_bmi= insurance["bmi"]> q3
print(insurance.loc[filtro_q1_bmi,"charges"].max())
filtro_q3_bmi= insurance["bmi"]> q3
print(insurance.loc[filtro_q1_bmi,"charges"].mean().round(2))
# Out:
# 1131.5066
# 63770.42801
# 14242.28

# %%
pokemon = pd.read_csv(r"C:\Users\Antonio Maurizi\Desktop\EPICODE_DATASET\datasets\beginner_datasets\pokemon.csv")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.size
# Out:
# 10400

# %%
pokemon.shape
# Out:
# (800, 13)

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon.sample(10)
# Out:
#        #       Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 199  184  Azumarill   Water   Fairy    420  100      50       80       60
# 81    75   Graveler    Rock  Ground    390   55      95      115       45
# 302  279   Pelipper   Water  Flying    430   60      50      100       85
# 355  324    Torkoal    Fire     NaN    470   70      85      140       85
# 52    47   Parasect     Bug   Grass    405   60      95       80       60
# 42    37     Vulpix    Fire     NaN    299   38      41       40       50
# 289  266    Silcoon     Bug     NaN    205   50      35       55       25
# 362  331     Cacnea   Grass     NaN    335   50      85       40       85
# 37    32   Nidoran♂  Poison     NaN    273   46      57       40       40
# 522  471    Glaceon     Ice     NaN    525   65      60      110      130
#
#      Sp. Def  Speed  Generation  Legendary
# 199       80     50           2      False
# 81        45     35           1      False
# ...

# %%
pokemon = pokemon.set_index(pokemon.columns[0])

# %%
pokemon.sample(10)
# Out:
#                         Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 676                  Furfrou    Normal     NaN    472   75      80       60
# 573                 Cinccino    Normal     NaN    470   75      95       60
# 524               Roggenrola      Rock     NaN    280   55      75       85
# 555  DarmanitanStandard Mode      Fire     NaN    480  105     140       55
# 189                 Jumpluff     Grass  Flying    460   75      55       70
# 334      AltariaMega Altaria    Dragon   Fairy    590   75     110      110
# 359                    Absol      Dark     NaN    465   65     130       60
# 447                    Riolu  Fighting     NaN    285   40      70       40
# 96                   Drowzee   Psychic     NaN    328   60      48       45
# 472                  Gliscor    Ground  Flying    510   75      95      125
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 676       65       90    102           6      False
# ...

# %%
pokemon["Legendary"].value_counts()
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %%
pokemon.describe
# Out:
# <bound method NDFrame.describe of                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pk_legendary= pokemon[ pokemon["Legendary"]]
print(pk_legendary["Name"])
# Out:
# #
# 144               Articuno
# 145                 Zapdos
# 146                Moltres
# 150                 Mewtwo
# 150    MewtwoMega Mewtwo X
#               ...
# 719                Diancie
# 719    DiancieMega Diancie
# 720    HoopaHoopa Confined
# 720     HoopaHoopa Unbound
# 721              Volcanion
# Name: Name, Length: 65, dtype: object

# %%
filtro_legendary=pokemon["Legendary"]==True
filtro_Type=pokemon["Type 1"]=="Grass"
filtro_pk_LT= filtro_legendary & filtro_Type
pokemon.loc[filtro_pk_LT,"Name"]
# Out:
# #
# 492    ShayminLand Forme
# 492     ShayminSky Forme
# 640             Virizion
# Name: Name, dtype: object

# %%
filtro_legendary=pokemon["Legendary"]==True
filtro_TypeI=pokemon["Type 1"]=="Ice"
filtro_TypeF=pokemon["Type 1"]=="Fire"
filtro_pk_LIF= filtro_legendary & filtro_TypeI | filtro_TypeF

pokemon.loc[filtro_pk_LIF,"Name"]
# Out:
# #
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 6      CharizardMega Charizard X
# 6      CharizardMega Charizard Y
# 37                        Vulpix
# 38                     Ninetales
# 58                     Growlithe
# 59                      Arcanine
# 77                        Ponyta
# 78                      Rapidash
# 126                       Magmar
# 136                      Flareon
# 144                     Articuno
# 146                      Moltres
# 155                    Cyndaquil
# 156                      Quilava
# 157                   Typhlosion
# 218                       Slugma
# 219                     Magcargo
# 240                        Magby
# 244                        Entei
# 250                        Ho-oh
# 255                      Torchic
# 256                    Combusken
# 257                     Blaziken
# 257        BlazikenMega Blaziken
# 322                        Numel
# ...

# %%
pokemon = pokemon.set_index(pokemon.columns[0])
print(pokemon.index)
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X',
#        'CharizardMega Charizard Y', 'Squirtle',
#        ...
#        'Noibat', 'Noivern', 'Xerneas', 'Yveltal', 'Zygarde50% Forme',
#        'Diancie', 'DiancieMega Diancie', 'HoopaHoopa Confined',
#        'HoopaHoopa Unbound', 'Volcanion'],
#       dtype='object', name='Name', length=800)

# %%
filtro_G=pokemon["Generation"]==1
filtro_A=pokemon["Attack"]>50
filtro_HP=pokemon["HP"]<60
filtro_pk_GAHP= filtro_G & filtro_A & filtro_HP

pokemon.loc[filtro_pk_GAHP]
# Out:
#             Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Charmander     NaN    309  39      52       43       60       50     65
# Charmeleon     NaN    405  58      64       58       80       65     80
# Wartortle      NaN    405  59      63       80       65       80     58
# Rattata        NaN    253  30      56       35       25       35     72
# Raticate       NaN    413  55      81       60       50       70     97
# Spearow     Flying    262  40      60       30       31       31     70
# Ekans          NaN    288  35      60       44       40       54     55
# Pikachu        NaN    320  35      55       40       50       50     90
# Sandshrew      NaN    300  50      75       85       20       30     40
# Nidoran♂       NaN    273  46      57       40       40       40     50
# Paras        Grass    285  35      70       55       45       55     25
# Diglett        NaN    265  10      55       25       35       45     95
# ...
